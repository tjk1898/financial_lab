# %%
# %load_ext autoreload
# %autoreload 2

# %%
from experiment_runner import Experiment
from strategy.Bolling import *
from util.dicts import *

# %%
test_files = '/Users/jinkun.tian/gitee/financial_lab/strategy/data/tmp/'
# exp_runner = Experiment(BollingV6, file_dir=test_files, start_date='2020-01-01')
exp_runner = Experiment(BollingV6, start_date='2014-01-01',end_date='2018-10-01')
exp_runner.run()

# %%
k_graph,own_money_line =exp_runner.get_graph_by_order(1)

# %%
k_graph.render_notebook()

# %%
own_money_line.render_notebook()

# %%
exp_runner.result_list

# %%
k_graph,own_money_line =exp_runner.get_graph_by_order(-2)

# %%
k_graph.render_notebook()

# %%
own_money_line.render_notebook()

# %%
exp_runner.result_list
# Out:
# [('000651', '格力电器', 251509.32),
#  ('002460', '赣锋锂业', 142382.76),
#  ('601668', '中国建筑', 124712.16),
#  ('600519', '贵州茅台', 124174.96),
#  ('600048', '保利发展', 115176.42),
#  ('600309', '万华化学', 109160.26),
#  ('601390', '中国中铁', 99371.39),
#  ('300059', '东方财富', 88087.12),
#  ('002352', '顺丰控股', 85528.6),
#  ('002493', '荣盛石化', 84520.15),
#  ('000333', '美的集团', 79809.24),
#  ('000858', '五粮液', 74635.2),
#  ('002415', '海康威视', 71550.21),
#  ('601012', '隆基绿能', 64904.84),
#  ('601225', '陕西煤业', 62691.92),
#  ('601318', '中国平安', 62528.05),
#  ('600900', '长江电力', 59439.3),
#  ('000002', '万科A', 58421.72),
#  ('002371', '北方华创', 58340.04),
#  ('600436', '片仔癀', 58005.36),
#  ('600585', '海螺水泥', 54845.02),
#  ('601088', '中国神华', 54067.8),
#  ('601939', '建设银行', 52805.97),
#  ('300014', '亿纬锂能', 52645.95),
#  ('300122', '智飞生物', 49933.52),
#  ('603799', '华友钴业', 47093.4),
#  ('600036', '招商银行', 47020.5),
#  ('601919', '中远海控', 45722.56),
#  ('600887', '伊利股份', 45279.64),
#  ('601328', '交通银行', 45201.6),
#  ('601818', '光大银行', 44749.95),
#  ('000725', '京东方A', 42487.06),
#  ('600690', '海尔智家', 42203.61),
#  ('601899', '紫金矿业', 39114.96),
#  ('002304', '洋河股份', 38595.78),
#  ('601988', '中国银行', 35268.7),
#  ('601166', '兴业银行', 35259.84),
#  ('000568', '泸州老窖', 34749.0),
#  ('600031', '三一重工', 34660.8),
#  ('600809', '山西汾酒', 34293.51),
#  ('002466', '天齐锂业', 34211.6),
#  ('600104', '上汽集团', 33596.48),
#  ('601601', '中国太保', 32069.79),
#  ('600030', '中信证券', 31529.51),
#  ('601628', '中国人寿', 30025.3),
#  ('002129', 'TCL中环', 29683.29),
#  ('601398', '工商银行', 28484.9),
#  ('002142', '宁波银行', 28462.27),
#  ('601998', '中信银行', 28171.33),
#  ('000001', '平安银行', 27314.1),
#  ('603288', '海天味业', 27205.15),
#  ('600438', '通威股份', 27045.17),
#  ('600276', '恒瑞医药', 26265.26),
#  ('300015', '爱尔眼科', 25954.56),
#  ('601288', '农业银行', 25924.32),
#  ('300274', '阳光电源', 25445.92),
#  ('601888', '中国中免', 24508.8),
#  ('600028', '中国石化', 23622.1),
#  ('600000', '浦发银行', 23384.79),
#  ('600406', '国电南瑞', 20282.52),
#  ('601633', '长城汽车', 19804.88),
#  ('600016', '民生银行', 19376.82),
#  ('300124', '汇川技术', 17343.2),
#  ('002812', '恩捷股份', 17166.96),
#  ('601857', '中国石油', 16479.25),
#  ('002594', '比亚迪', 14937.65),
#  ('000792', '盐湖股份', 14674.92),
#  ('002459', '晶澳科技', 12762.7),
#  ('002475', '立讯精密', 12542.4),
#  ('600346', '恒力石化', -20000.0)]

# %%
k_graph,own_money_line =exp_runner.get_graph_by_order(-2)

# %%
k_graph.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="73d5f6998cba45ba82b00d86d7f365d6" style="width:900px; height:580px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_73d5f6998cba45ba82b00d86d7f365d6 = echarts.init(
#                     document.getElementById('73d5f6998cba45ba82b00d86d7f365d6'), 'light', {renderer: 'canvas'});
#                 var option_73d5f6998cba45ba82b00d86d7f365d6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "K\u7ebf",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     4.0,
#                     4.03,
#                     4.06,
#                     3.89
#                 ],
#                 [
#                     4.01,
#                     4.09,
#                     4.14,
#                     3.97
#                 ],
#                 [
#                     4.06,
#                     4.01,
#                     4.14,
#                     4.0
#                 ],
#                 [
#                     4.03,
#                     3.96,
#                     4.03,
#                     3.89
#                 ],
#                 [
#                     3.96,
#                     3.94,
#                     4.01,
#                     3.9
#                 ],
#                 [
#                     3.94,
#                     3.93,
#                     3.96,
#                     3.79
#                 ],
#                 [
#                     3.93,
#                     3.84,
#                     3.93,
#                     3.83
#                 ],
#                 [
#                     3.83,
#                     3.67,
#                     3.85,
#                     3.65
#                 ],
#                 [
#                     3.67,
#                     3.53,
#                     3.75,
#                     3.47
#                 ],
#                 [
#                     3.52,
#                     3.73,
#                     3.76,
#                     3.52
#                 ],
#                 [
#                     3.7,
#                     3.55,
#                     3.79,
#                     3.55
#                 ],
#                 [
#                     3.57,
#                     3.45,
#                     3.63,
#                     3.4
#                 ],
#                 [
#                     3.45,
#                     3.46,
#                     3.55,
#                     3.37
#                 ],
#                 [
#                     3.43,
#                     3.47,
#                     3.51,
#                     3.42
#                 ],
#                 [
#                     3.53,
#                     3.6,
#                     3.65,
#                     3.5
#                 ],
#                 [
#                     3.59,
#                     3.7,
#                     3.71,
#                     3.57
#                 ],
#                 [
#                     3.7,
#                     3.66,
#                     3.75,
#                     3.6
#                 ],
#                 [
#                     3.66,
#                     3.5,
#                     3.7,
#                     3.49
#                 ],
#                 [
#                     3.6,
#                     3.63,
#                     3.75,
#                     3.57
#                 ],
#                 [
#                     3.65,
#                     3.63,
#                     3.69,
#                     3.55
#                 ],
#                 [
#                     3.65,
#                     3.77,
#                     3.77,
#                     3.63
#                 ],
#                 [
#                     3.79,
#                     3.73,
#                     3.79,
#                     3.7
#                 ],
#                 [
#                     3.73,
#                     3.77,
#                     3.79,
#                     3.7
#                 ],
#                 [
#                     3.73,
#                     3.67,
#                     3.81,
#                     3.63
#                 ],
#                 [
#                     3.64,
#                     3.69,
#                     3.69,
#                     3.5
#                 ],
#                 [
#                     3.65,
#                     3.64,
#                     3.67,
#                     3.57
#                 ],
#                 [
#                     3.64,
#                     3.73,
#                     3.75,
#                     3.63
#                 ],
#                 [
#                     3.76,
#                     3.8,
#                     3.83,
#                     3.7
#                 ],
#                 [
#                     3.79,
#                     3.78,
#                     3.88,
#                     3.75
#                 ],
#                 [
#                     3.83,
#                     3.83,
#                     3.87,
#                     3.74
#                 ],
#                 [
#                     3.79,
#                     4.01,
#                     4.03,
#                     3.79
#                 ],
#                 [
#                     4.01,
#                     4.25,
#                     4.26,
#                     4.01
#                 ],
#                 [
#                     4.25,
#                     4.23,
#                     4.49,
#                     4.15
#                 ],
#                 [
#                     4.25,
#                     4.19,
#                     4.29,
#                     4.16
#                 ],
#                 [
#                     4.23,
#                     4.2,
#                     4.3,
#                     4.19
#                 ],
#                 [
#                     4.21,
#                     4.23,
#                     4.29,
#                     4.19
#                 ],
#                 [
#                     4.23,
#                     4.17,
#                     4.24,
#                     4.13
#                 ],
#                 [
#                     4.13,
#                     4.19,
#                     4.2,
#                     4.05
#                 ],
#                 [
#                     4.19,
#                     4.13,
#                     4.19,
#                     4.1
#                 ],
#                 [
#                     4.17,
#                     4.13,
#                     4.17,
#                     4.03
#                 ],
#                 [
#                     4.13,
#                     4.01,
#                     4.14,
#                     3.99
#                 ],
#                 [
#                     4.01,
#                     3.98,
#                     4.03,
#                     3.93
#                 ],
#                 [
#                     4.0,
#                     4.04,
#                     4.05,
#                     3.95
#                 ],
#                 [
#                     4.06,
#                     4.21,
#                     4.3,
#                     4.06
#                 ],
#                 [
#                     4.22,
#                     4.25,
#                     4.32,
#                     4.15
#                 ],
#                 [
#                     4.25,
#                     4.25,
#                     4.26,
#                     4.16
#                 ],
#                 [
#                     4.24,
#                     4.25,
#                     4.28,
#                     4.19
#                 ],
#                 [
#                     4.24,
#                     4.19,
#                     4.24,
#                     4.14
#                 ],
#                 [
#                     4.18,
#                     4.13,
#                     4.21,
#                     4.09
#                 ],
#                 [
#                     4.13,
#                     4.11,
#                     4.2,
#                     4.08
#                 ],
#                 [

# %%
own_money_line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4075c89564e044d49e27fa089518b31e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4075c89564e044d49e27fa089518b31e = echarts.init(
#                     document.getElementById('4075c89564e044d49e27fa089518b31e'), 'white', {renderer: 'canvas'});
#                 var option_4075c89564e044d49e27fa089518b31e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7acb\u8baf\u7cbe\u5bc6",
#             "connectNulls": true,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2014-07-01",
#                     null
#                 ],
#                 [
#                     "2014-07-02",
#                     null
#                 ],
#                 [
#                     "2014-07-03",
#                     null
#                 ],
#                 [
#                     "2014-07-04",
#                     null
#                 ],
#                 [
#                     "2014-07-07",
#                     null
#                 ],
#                 [
#                     "2014-07-08",
#                     null
#                 ],
#                 [
#                     "2014-07-09",
#                     9457.92
#                 ],
#                 [
#                     "2014-07-10",
#                     null
#                 ],
#                 [
#                     "2014-07-11",
#                     null
#                 ],
#                 [
#                     "2014-07-14",
#                     null
#                 ],
#                 [
#                     "2014-07-15",
#                     null
#                 ],
#                 [
#                     "2014-07-16",
#                     null
#                 ],
#                 [
#                     "2014-07-17",
#                     null
#                 ],
#                 [
#                     "2014-07-18",
#                     null
#                 ],
#                 [
#                     "2014-07-21",
#                     null
#                 ],
#                 [
#                     "2014-07-22",
#                     null
#                 ],
#                 [
#                     "2014-07-23",
#                     null
#                 ],
#                 [
#                     "2014-07-24",
#                     null
#                 ],
#                 [
#                     "2014-07-25",
#                     null
#                 ],
#                 [
#                     "2014-07-28",
#                     null
#                 ],
#                 [
#                     "2014-07-29",
#                     null
#                 ],
#                 [
#                     "2014-07-30",
#                     null
#                 ],
#                 [
#                     "2014-07-31",
#                     null
#                 ],
#                 [
#                     "2014-08-01",
#                     null
#                 ],
#                 [
#                     "2014-08-04",
#                     null
#                 ],
#                 [
#                     "2014-08-05",
#                     null
#                 ],
#                 [
#                     "2014-08-06",
#                     null
#                 ],
#                 [
#                     "2014-08-07",
#                     null
#                 ],
#                 [
#                     "2014-08-08",
#                     null
#                 ],
#                 [
#                     "2014-08-11",
#                     null
#                 ],
#                 [
#                     "2014-08-12",
#                     null
#                 ],
#                 [
#                     "2014-08-13",
#                     null
#                 ],
#                 [
#                     "2014-08-14",
#                     null
#                 ],
#                 [
#                     "2014-08-15",
#                     null
#                 ],
#                 [
#                     "2014-08-18",
#                     null
#                 ],
#                 [
#                     "2014-08-19",
#                     null
#                 ],
#                 [
#                     "2014-08-20",
#                     null
#                 ],
#                 [
#                     "2014-08-21",
#                     null
#                 ],
#                 [
#                     "2014-08-22",
#                     null
#                 ],
#                 [
#                     "2014-08-25",
#                     null
#                 ],
#                 [
#                     "2014-08-26",
#                     9724.25
#                 ],
#                 [
#                     "2014-08-27",
#                     null
#                 ],
#                 [
#                     "2014-08-28",
#                     null
#                 ],
#                 [
#                     "2014-08-29",
#                     null
#                 ],
#                 [
#                     "2014-09-01",
#                     null
#                 ],
#                 [
#                     "2014-09-02",
#                     null
#                 ],
#                 [
#                     "2014-09-03",
#                     null
#                 ],
#                 [
#                     "2014-09-04",
#                     null
#                 ],
#                 [
#                     "2014-09-05",
#                     9870.7
#                 ],
#                 [
#                     "2014-09-09",
#                     null
#                 ],
#                 [
#                     "2014-09-10",
#                     null
#                 ],
#                 [
#                     "2014-09-11",
#                     9765.36
#                 ],
#                 [
#                     "2014-09-12",
#                     null
#                 ],
#                 [
#                     "2014-09-15",
#                     null
#                 ],
#                 [
#                     "2014-09-16",
#                     null
#                 ],
#                 [
#                     "2014-09-17",
#                     null
#                 ],
#                 [
#                     "2014-09-18",
#                     null
#                 ],
#                 [
#                     "2014-09-19",
#                     null
#                 ],
#                 [
#                     "2014-09-22",
#                     null
#                 ],
#                 [
#                     "2014-09-23",
#                     null
#                 ],
#                 [
#                     "2014-09-24",
#                     null
#                 ],
#                 [
#                     "2014-09-25",
#                     null
#                 ],
#                 [
#                     "2014-09-26",
#                     null
#                 ],
#                 [
#                     "2014-09-29",
#                     null
#                 ],
#                 [
#                     "2014-09-30",
#                     null
#                 ],
#                 [
#                     "2014-10-08",
#                     null
#                 ],
#                 [
#                     "2014-10-09",
