# %%
# %load_ext autoreload
# %autoreload 2

# %%
from experiment_runner import Experiment
from strategy.Bolling import *
from util.dicts import *

# %%
test_files = '/Users/jinkun.tian/gitee/financial_lab/strategy/data/tmp/'
# exp_runner = Experiment(BollingV6, file_dir=test_files, start_date='2020-01-01')
exp_runner = Experiment(BollingV6, start_date='2014-01-01')
exp_runner.run()
# Out:
# 2022-07-16 20:16:22,642 - root - INFO - procees:300999.SZ.csv
# 2022-07-16 20:16:22,938 - root - INFO - 交易次数：8
# 2022-07-16 20:16:22,950 - root - INFO - procees:000651.SZ.csv
# 2022-07-16 20:16:23,365 - root - INFO - 交易次数：11
# 2022-07-16 20:16:23,383 - root - INFO - procees:000568.SZ.csv
# 2022-07-16 20:16:23,814 - root - INFO - 交易次数：11

# %%
k_graph,own_money_line =exp_runner.get_graph_by_order(1)

# %%
k_graph.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f45d59d4c47940388b30966dd82fc0d6" style="width:900px; height:580px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f45d59d4c47940388b30966dd82fc0d6 = echarts.init(
#                     document.getElementById('f45d59d4c47940388b30966dd82fc0d6'), 'light', {renderer: 'canvas'});
#                 var option_f45d59d4c47940388b30966dd82fc0d6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "K\u7ebf",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "data": [
#                 [
#                     81.19,
#                     79.13,
#                     81.35,
#                     79.13
#                 ],
#                 [
#                     77.89,
#                     74.44,
#                     77.89,
#                     74.42
#                 ],
#                 [
#                     74.44,
#                     73.86,
#                     76.49,
#                     72.69
#                 ],
#                 [
#                     74.32,
#                     74.05,
#                     74.59,
#                     73.07
#                 ],
#                 [
#                     72.75,
#                     72.13,
#                     75.39,
#                     71.34
#                 ],
#                 [
#                     71.65,
#                     72.09,
#                     72.36,
#                     69.96
#                 ],
#                 [
#                     72.28,
#                     74.73,
#                     74.73,
#                     71.31
#                 ],
#                 [
#                     74.15,
#                     74.31,
#                     76.64,
#                     73.57
#                 ],
#                 [
#                     73.61,
#                     75.73,
#                     76.38,
#                     73.3
#                 ],
#                 [
#                     75.89,
#                     77.01,
#                     77.59,
#                     74.69
#                 ],
#                 [
#                     76.79,
#                     78.81,
#                     81.19,
#                     76.4
#                 ],
#                 [
#                     78.2,
#                     75.39,
#                     79.17,
#                     75.31
#                 ],
#                 [
#                     74.9,
#                     75.19,
#                     76.22,
#                     73.55
#                 ],
#                 [
#                     74.89,
#                     78.39,
#                     78.72,
#                     74.04
#                 ],
#                 [
#                     78.64,
#                     78.93,
#                     80.69,
#                     77.19
#                 ],
#                 [
#                     81.5,
#                     78.58,
#                     82.6,
#                     78.15
#                 ],
#                 [
#                     77.73,
#                     74.65,
#                     78.0,
#                     74.0
#                 ],
#                 [
#                     74.2,
#                     73.9,
#                     76.35,
#                     73.88
#                 ],
#                 [
#                     73.8,
#                     74.43,
#                     75.07,
#                     72.11
#                 ],
#                 [
#                     73.5,
#                     76.82,
#                     76.85,
#                     73.0
#                 ],
#                 [
#                     76.12,
#                     76.2,
#                     76.75,
#                     75.11
#                 ],
#                 [
#                     75.0,
#                     74.2,
#                     75.6,
#                     74.04
#                 ],
#                 [
#                     74.78,
#                     78.97,
#                     80.0,
#                     74.2
#                 ],
#                 [
#                     79.16,
#                     81.35,
#                     83.6,
#                     79.16
#                 ],
#                 [
#                     81.82,
#                     83.13,
#                     84.13,
#                     81.82
#                 ],
#                 [
#                     83.0,
#                     82.07,
#                     83.89,
#                     81.77
#                 ],
#                 [
#                     82.29,
#                     81.41,
#                     83.99,
#                     81.37
#                 ],
#                 [
#                     81.63,
#                     79.82,
#                     82.19,
#                     79.22
#                 ],
#                 [
#                     79.81,
#                     90.01,
#                     90.18,
#                     79.81
#                 ],
#                 [
#                     90.22,
#                     92.3,
#                     92.66,
#                     88.07
#                 ],
#                 [
#                     92.28,
#                     90.31,
#                     96.0,
#                     90.01
#                 ],
#                 [
#                     91.25,
#                     91.85,
#                     92.71,
#                     88.88
#                 ],
#                 [
#                     91.2,
#                     91.19,
#                     93.14,
#                     89.61
#                 ],
#                 [
#                     91.0,
#                     92.02,
#                     92.2,
#                     88.66
#                 ],
#                 [
#                     91.5,
#                     91.4,
#                     91.83,
#                     89.66
#                 ],
#                 [
#                     91.7,
#                     90.72,
#                     95.0,
#                     90.71
#                 ],
#                 [
#                     90.72,
#                     96.36,
#                     98.5,
#                     88.51
#                 ],
#                 [
#                     94.97,
#                     96.16,
#                     97.67,
#                     94.56
#                 ],
#                 [
#                     96.17,
#                     99.75,
#                     100.77,
#                     95.02
#                 ],
#                 [
#                     99.87,
#                     92.02,
#                     99.87,
#                     90.25
#                 ],
#                 [
#                     91.2,
#                     92.55,
#                     94.33,
#                     91.01
#                 ],
#                 [
#                     92.88,
#                     94.8,
#                     95.99,
#                     92.3
#                 ],
#                 [
#                     94.13,
#                     91.77,
#                     94.49,
#                     90.9
#                 ],
#                 [
#                     91.51,
#                     92.19,
#                     94.57,
#                     90.85
#                 ],
#                 [
#                     92.25,
#                     86.75,
#                     92.38,
#                     86.17
#                 ],
#                 [
#                     86.98,
#                     88.52,
#                     89.44,
#                     86.68
#                 ],
#                 [
#                     88.85,
#                     87.5,
#                     89.28,
#                     86.0
#                 ],
#                 [
#                     87.0,
#                     86.3,
#                     88.0,
#                     85.28
#                 ],
#                 [
#                     86.6,
#                     88.16,
#                     88.63,
#                     86.6

# %%
own_money_line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8241e6ede6484b76b7af3f3b9d784b35" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8241e6ede6484b76b7af3f3b9d784b35 = echarts.init(
#                     document.getElementById('8241e6ede6484b76b7af3f3b9d784b35'), 'white', {renderer: 'canvas'});
#                 var option_8241e6ede6484b76b7af3f3b9d784b35 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u91d1\u9f99\u9c7c",
#             "connectNulls": true,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2021-04-09",
#                     null
#                 ],
#                 [
#                     "2021-04-12",
#                     null
#                 ],
#                 [
#                     "2021-04-13",
#                     null
#                 ],
#                 [
#                     "2021-04-14",
#                     null
#                 ],
#                 [
#                     "2021-04-15",
#                     null
#                 ],
#                 [
#                     "2021-04-16",
#                     null
#                 ],
#                 [
#                     "2021-04-19",
#                     null
#                 ],
#                 [
#                     "2021-04-20",
#                     null
#                 ],
#                 [
#                     "2021-04-21",
#                     null
#                 ],
#                 [
#                     "2021-04-22",
#                     null
#                 ],
#                 [
#                     "2021-04-23",
#                     null
#                 ],
#                 [
#                     "2021-04-26",
#                     null
#                 ],
#                 [
#                     "2021-04-27",
#                     null
#                 ],
#                 [
#                     "2021-04-28",
#                     null
#                 ],
#                 [
#                     "2021-04-29",
#                     null
#                 ],
#                 [
#                     "2021-04-30",
#                     null
#                 ],
#                 [
#                     "2021-05-06",
#                     null
#                 ],
#                 [
#                     "2021-05-07",
#                     null
#                 ],
#                 [
#                     "2021-05-10",
#                     null
#                 ],
#                 [
#                     "2021-05-11",
#                     null
#                 ],
#                 [
#                     "2021-05-12",
#                     null
#                 ],
#                 [
#                     "2021-05-13",
#                     null
#                 ],
#                 [
#                     "2021-05-14",
#                     null
#                 ],
#                 [
#                     "2021-05-17",
#                     null
#                 ],
#                 [
#                     "2021-05-18",
#                     null
#                 ],
#                 [
#                     "2021-05-19",
#                     null
#                 ],
#                 [
#                     "2021-05-20",
#                     null
#                 ],
#                 [
#                     "2021-05-21",
#                     9658.22
#                 ],
#                 [
#                     "2021-05-24",
#                     null
#                 ],
#                 [
#                     "2021-05-25",
#                     null
#                 ],
#                 [
#                     "2021-05-26",
#                     null
#                 ],
#                 [
#                     "2021-05-27",
#                     null
#                 ],
#                 [
#                     "2021-05-28",
#                     null
#                 ],
#                 [
#                     "2021-05-31",
#                     null
#                 ],
#                 [
#                     "2021-06-01",
#                     null
#                 ],
#                 [
#                     "2021-06-02",
#                     null
#                 ],
#                 [
#                     "2021-06-03",
#                     null
#                 ],
#                 [
#                     "2021-06-04",
#                     null
#                 ],
#                 [
#                     "2021-06-07",
#                     null
#                 ],
#                 [
#                     "2021-06-08",
#                     null
#                 ],
#                 [
#                     "2021-06-09",
#                     null
#                 ],
#                 [
#                     "2021-06-10",
#                     null
#                 ],
#                 [
#                     "2021-06-11",
#                     null
#                 ],
#                 [
#                     "2021-06-15",
#                     null
#                 ],
#                 [
#                     "2021-06-16",
#                     10236.5
#                 ],
#                 [
#                     "2021-06-17",
#                     null
#                 ],
#                 [
#                     "2021-06-18",
#                     null
#                 ],
#                 [
#                     "2021-06-21",
#                     null
#                 ],
#                 [
#                     "2021-06-22",
#                     null
#                 ],
#                 [
#                     "2021-06-23",
#                     null
#                 ],
#                 [
#                     "2021-06-24",
#                     null
#                 ],
#                 [
#                     "2021-06-25",
#                     null
#                 ],
#                 [
#                     "2021-06-28",
#                     null
#                 ],
#                 [
#                     "2021-06-29",
#                     null
#                 ],
#                 [
#                     "2021-06-30",
#                     null
#                 ],
#                 [
#                     "2021-07-01",
#                     null
#                 ],
#                 [
#                     "2021-07-02",
#                     null
#                 ],
#                 [
#                     "2021-07-05",
#                     null
#                 ],
#                 [
#                     "2021-07-06",
#                     null
#                 ],
#                 [
#                     "2021-07-07",
#                     null
#                 ],
#                 [
#                     "2021-07-08",
#                     null
#                 ],
#                 [
#                     "2021-07-09",
#                     null
#                 ],
#                 [
#                     "2021-07-12",
#                     null
#                 ],
#                 [
#                     "2021-07-13",
#                     null
#                 ],
#                 [
#                     "2021-07-14",
#                     null
#                 ],
#                 [
#                     "2021-07-15",
#                     null
#                 ],
#                 [
#                     "2021-07-16",
#                     null
