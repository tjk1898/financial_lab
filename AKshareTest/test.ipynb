# %%
import akshare as ak
import columns as columns
import pandas as pd

# %%
stock_zh_a_spot_df = ak.stock_zh_a_spot()
stock_zh_a_spot_df

# %%
stock_zh_a_cdr_daily_df = ak.stock_zh_a_cdr_daily("sh601888", "20220324", "20220424");
print(stock_zh_a_cdr_daily_df)
# Out:
#           date    open    high     low   close      volume
# 0   2022-03-24  168.00  168.80  165.60  166.62   7225312.0
# 1   2022-03-25  167.33  168.90  162.50  162.85   7524638.0
# 2   2022-03-28  157.82  161.97  157.08  159.50   9803836.0
# 3   2022-03-29  159.81  161.65  155.73  156.10   8267156.0
# 4   2022-03-30  159.22  168.39  156.88  167.20  15229175.0
# 5   2022-03-31  164.02  167.10  163.40  164.37   8257219.0
# 6   2022-04-01  162.64  177.30  162.22  174.26  19300145.0
# 7   2022-04-06  168.20  168.60  163.00  164.10  20632182.0
# 8   2022-04-07  161.80  167.40  161.37  164.95  12995661.0
# 9   2022-04-08  163.91  165.70  160.81  164.48   9303584.0
# 10  2022-04-11  161.19  161.19  153.59  156.11  16885384.0
# 11  2022-04-12  157.80  171.72  157.55  171.72  19192813.0
# 12  2022-04-13  175.80  176.80  169.72  172.00  23182403.0
# 13  2022-04-14  174.76  185.10  174.76  181.58  23491915.0
# 14  2022-04-15  178.30  185.80  177.17  182.24  14388167.0
# ...

# %%
ak.stock_zh_a_scr_report("2022", "1")
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  6.68it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 ak.stock_zh_a_scr_report("2022","1")
#
# File ~/gitee/financial_lab/venv/lib/python3.8/site-packages/akshare/stock/stock_zh_zrbg_hx.py:63, in stock_zh_a_scr_report(year, need_page)
#      60 big_df["index"] = big_df.index + 1
#      61 big_df.rename({"index": "序号"}, axis="columns", inplace=True)
#      62 big_df["股票代码"] = (
# ---> 63     big_df["股票名称"].str.split("(", expand=True).iloc[:, 1].str.strip(")")
#      64 )
#      65 big_df["股票名称"] = big_df["股票名称"].str.split("(", expand=True).iloc[:, 0]
#      66 big_df["股东责任"] = pd.to_numeric(big_df["股东责任"])
#
# File ~/gitee/financial_lab/venv/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
# ...

# %%
ak.stock_comment_em()
# Out:
#         序号      代码       名称    最新价   涨跌幅   换手率    市盈率       主力成本     机构参与度  \
# 0        1  000001     平安银行  16.06  1.58  0.47   8.58  15.939371  0.515580
# 1        2  000002    万  科Ａ  19.81  2.64  1.14  10.22  19.746368  0.548547
# 2        3  000004     国华网安  16.42 -0.36  1.99  56.95  16.522146  0.136948
# 3        4  000005     ST星源   2.31  2.67  2.00   9.44   2.307330  0.329356
# 4        5  000006     深振业Ａ   4.37 -1.13  1.58  10.89   4.387763  0.233861
# ...    ...     ...      ...    ...   ...   ...    ...        ...       ...
# 4612  4613  688799     华纳药厂  31.81  0.82  1.94  21.88  31.435078  0.107815
# 4613  4614  688800      瑞可达  88.04 -4.06  1.74  83.51  88.689812  0.096985
# 4614  4615  688819     天能股份  27.05 -1.99  0.91  19.20  27.294298  0.084805
# 4615  4616  688981     中芯国际  41.85 -0.10  0.56  30.84  41.887798  0.327003
# 4616  4617  689009  九号公司-WD  36.83 -1.79  0.07  62.84  37.092599  0.109666
#
#            综合得分    上升  目前排名  关注指数         交易日
# ...

# %%
# # 指数实时行情和历史行情
# "stock_zh_index_daily"  # 股票指数历史行情数据
# "stock_zh_index_daily_tx"  # 股票指数历史行情数据-腾讯
# "stock_zh_index_daily_em"  # 股票指数历史行情数据-东方财富
# "stock_zh_index_spot"  # 股票指数实时行情数据
# # 股票分笔数据
# "stock_zh_a_tick_tx"  # A 股票分笔行情数据(近2年)-腾讯
# "stock_zh_a_tick_tx_js"  # A 股票分笔行情数据(近2年)-腾讯-当日数据
# "stock_zh_a_tick_163"  # A 股票分笔行情数据(近5个交易日)-163

# A+H股实时行情数据和历史行情数据
"stock_zh_ah_spot"  # 获取 A+H 股实时行情数据(延迟15分钟)
"stock_zh_ah_daily"  # 获取 A+H 股历史行情数据(日频)
"stock_zh_ah_name"  # 获取 A+H 股所有股票代码
# A股实时行情数据和历史行情数据
"stock_zh_a_spot"  # 获取 A 股实时行情数据
"stock_zh_a_daily"  # 获取 A 股历史行情数据(日频)
"stock_zh_a_minute"  # 获取 A 股分时历史行情数据(分钟)
"stock_zh_a_cdr_daily"  # 获取 A 股 CDR 历史行情数据(日频)
# 科创板实时行情数据和历史行情数据
"stock_zh_kcb_spot"  # 获取科创板实时行情数据
"stock_zh_kcb_daily"  # 获取科创板历史行情数据(日频)

# 千股千评
"stock_comment_em"  # 股市关注度
"stock_comment_detail_zlkp_jgcyd_em"  # 机构参与度
"stock_comment_detail_zhpj_lspf_em"  # 综合评价-历史评分
"stock_comment_detail_scrd_focus_em"  # 市场热度-用户关注指数
"stock_comment_detail_scrd_desire_em"  # 市场热度-市场参与意愿
"stock_comment_detail_scrd_cost_em"  # 市场热度-市场成本

# 沪深港通
"stock_hk_ggt_components_em"  # 港股通成份股
"stock_hsgt_north_net_flow_in_em"  # 沪深港通北向-净流入
"stock_hsgt_north_cash_em"  # 沪深港通北向-资金余额
"stock_hsgt_north_acc_flow_in_em"  # 沪深港通北向-累计净流入
"stock_hsgt_south_net_flow_in_em"  # 沪深港通南向-净流入
"stock_hsgt_south_cash_em"  # 沪深港通南向-资金余额
"stock_hsgt_south_acc_flow_in_em"  # 沪深港通南向-累计净流入
"stock_hsgt_hold_stock_em"  # 沪深港通持股-个股排行
"stock_hsgt_stock_statistics_em"  # 沪深港通持股-每日个股统计
"stock_hsgt_institution_statistics_em"  # 沪深港通持股-每日机构统计
"stock_hsgt_hist_em"  # 沪深港通历史数据
"stock_hsgt_board_rank_em"  # 板块排行

# 个股资金流
"stock_individual_fund_flow"  # 个股资金流
"stock_individual_fund_flow_rank"  # 个股资金流排名
"stock_market_fund_flow"  # 大盘资金流
"stock_sector_fund_flow_rank"  # 板块资金流排名

# 股票基本面数据
"stock_financial_abstract"  # 财务摘要
"stock_financial_report_sina"  # 三大财务报表
"stock_financial_analysis_indicator"  # 财务指标
"stock_add_stock"  # 股票增发
"stock_ipo_info"  # 股票新股
"stock_history_dividend_detail"  # 分红配股
"stock_history_dividend"  # 历史分红
"stock_dividents_cninfo"  # 个股历史分红
"stock_restricted_shares"  # 限售解禁
"stock_circulate_stock_holder"  # 流动股东
"stock_fund_stock_holder"  # 基金持股
"stock_main_stock_holder"  # 主要股东
# 股票板块
"stock_sector_spot"  # 板块行情
"stock_sector_detail"  # 板块详情(具体股票)

# 股票信息
"stock_info_sz_name_code"  # 深证证券交易所股票代码和简称
"stock_info_sh_name_code"  # 上海证券交易所股票代码和简称
"stock_info_bj_name_code"  # 北京证券交易所股票代码和简称
"stock_info_sh_delist"  # 上海证券交易所暂停和终止上市
"stock_info_sz_delist"  # 深证证券交易所暂停和终止上市
"stock_info_sz_change_name"  # 深证证券交易所股票曾用名详情
"stock_info_change_name"  # A 股股票曾用名列表
"stock_info_a_code_name"  # A 股股票代码和简称

# 机构持股
"stock_institute_hold"  # 机构持股一览表
"stock_institute_hold_detail"  # 机构持股详情
# 机构推荐股票
"stock_institute_recommend"  # 机构推荐
"stock_institute_recommend_detail"  # 股票评级记录

# 股票市场总貌
"stock_szse_summary"  # 深圳证券交易所-市场总貌
"stock_sse_summary"  # 上海证券交易所-股票数据总貌
"stock_sse_deal_daily"  # 上海证券交易所-每日股票情况

# A 股市盈率和市净率
"stock_a_pb"  # A 股市净率
"stock_a_pe"  # A 股市盈率
"stock_a_pe_and_pb"  # A 股市盈率和市净率
"stock_a_lg_indicator"  # A 股个股市盈率、市净率和股息率指标
"stock_hk_eniu_indicator"  # 港股股个股市盈率、市净率和股息率指标
"stock_a_high_low_statistics"  # 创新高和新低的股票数量
"stock_a_below_net_asset_statistics"  # 破净股统计

# 中证指数
"stock_zh_index_hist_csindex"  # 中证指数
"stock_zh_index_value_csindex"  # 中证指数-指数估值

# 次新股
"stock_zh_a_new"  # 股票数据-次新股

# 科创板报告
"stock_zh_kcb_report_em"  # 科创板报告

# 股东户数
"stock_zh_a_gdhs"  # 股东户数
"stock_zh_a_gdhs_detail_em"  # 股东户数详情

# A 股日频率数据-东方财富
"stock_zh_a_hist"  # A 股日频率数据-东方财富

# 养猪数据中心
"futures_pig_info"  # 生猪信息
"futures_pig_rank"  # 生猪价格排行

# A 股分时数据
"stock_zh_a_hist_min_em"  # 东财-股票分时
"stock_zh_a_hist_pre_min_em"  # 东财-股票盘前分时

# 风险警示板
"stock_zh_a_st_em"  # 风险警示板

# B 股实时行情数据和历史行情数据
"stock_zh_b_spot"  # B 股实时行情数据
"stock_zh_b_daily"  # B 股历史行情数据(日频)
"stock_zh_b_minute"  # B 股分时历史行情数据(分钟)

# 沪深港通持股
"stock_hsgt_individual_em"  # 沪深港通持股-具体股票
"stock_hsgt_individual_detail_em"  # 沪深港通持股-具体股票-详情

# 同花顺-数据中心-技术选股-创新高
"stock_rank_cxg_ths"  # 创新高
"stock_rank_cxd_ths"  # 创新低
"stock_rank_lxsz_ths"  # 连续上涨
"stock_rank_lxxd_ths"  # 连续下跌
"stock_rank_cxfl_ths"  # 持续放量
"stock_rank_cxsl_ths"  # 持续缩量
"stock_rank_xstp_ths"  # 向上突破
"stock_rank_xxtp_ths"  # 向下突破
"stock_rank_ljqs_ths"  # 量价齐升
"stock_rank_ljqd_ths"  # 量价齐跌
"stock_rank_xzjp_ths"  # 险资举牌

# 行业板块
"stock_board_industry_cons_em"  # 行业板块-板块成份
"stock_board_industry_hist_em"  # 行业板块-历史行情
"stock_board_industry_hist_min_em"  # 行业板块-分时历史行情
"stock_board_industry_name_em"  # 行业板块-板块名称

# %%
print(ak.stock_board_industry_name_em())
ak.stock_board_industry_cons_em()
# Out:
#     排名    板块名称    板块代码       最新价      涨跌额   涨跌幅            总市值   换手率  上涨家数  \
# 0    1    水泥建材  BK0424  26774.32  1111.22  4.33   604934224000  1.31    28
# 1    2    工程建设  BK0425  17966.81   425.67  2.43  1492335072000  1.16    49
# 2    3  工程咨询服务  BK0726    512.95     4.19  0.82   123753311000  2.70    27
# 3    4    航天航空  BK0480  29293.22   142.23  0.49   579616912000  0.46    20
# 4    5    工程机械  BK0739    773.03     0.86  0.11   423890592000  0.50    14
# ..  ..     ...     ...       ...      ...   ...            ...   ...   ...
# 81  82    汽车整车  BK1029    808.76   -26.30 -3.15  1436632976000  0.38     0
# 82  83    贸易行业  BK0484   6823.21  -236.56 -3.35   248417625000  0.86     1
# 83  84    食品饮料  BK0438  20008.70  -737.36 -3.55  1843113984000  0.78     9
# 84  85    商业百货  BK0482  12591.85  -497.16 -3.80   478206304000  1.28     8
# 85  86    纺织服装  BK0436   8413.64  -515.65 -5.77   483530672000  0.94     6
#
#     下跌家数  领涨股票  领涨股票-涨跌幅
# 0      3  龙泉股份     10.09
# ...

# %%
# 指数历史数据
"index_zh_a_hist"  # 中国股票指数历史数据
# 指数分时数据
"index_zh_a_hist_min_em"  # 中国股票指数-指数分时数据

# 网易财经-行情首页-沪深 A 股-每日行情
"stock_zh_a_hist_163"  # 网易财经-行情首页-沪深 A 股-每日行情

# %%
# 行业板块
stock_board_industry_name_em_df = ak.stock_board_industry_name_em()
print(stock_board_industry_name_em_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # 行业板块
# ----> 2 stock_board_industry_name_em_df = ak.stock_board_industry_name_em()
#       3 print(stock_board_industry_name_em_df)
#
# NameError: name 'ak' is not defined

# %%
# 行业资金流入
stock_fund_flow_industry_df = ak.stock_fund_flow_industry(symbol="即时")
print(stock_fund_flow_industry_df)

# 个股历史资金流入
stock_individual_fund_flow_df = ak.stock_individual_fund_flow(stock="600094", market="sh")
print(stock_individual_fund_flow_df)

# 行业历史资金流入

# 大盘资金流动
stock_market_fund_flow_df = ak.stock_market_fund_flow()
print(stock_market_fund_flow_df)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  4.52it/s]
#     序号       行业      行业指数  行业-涨跌幅   流入资金   流出资金     净额  公司家数    领涨股  领涨股-涨跌幅  \
# 0    1     纺织制造  1771.930    6.20  18.80  15.68   3.12    34    万事利    19.99
# 1    2     服装家纺  2212.580    5.17  22.73  21.01   1.72    62   恒辉安防    20.02
# 2    3  油气开采及服务  1003.210    2.95  44.76  26.99  17.77    22   中曼石油    10.01
# 3    4       电力  1280.210    2.68  74.31  56.74  17.57    95   内蒙华电    10.06
# 4    5     港口航运   828.075    2.52  23.31  17.76   5.55    32   盛航股份    10.00
# ..  ..      ...       ...     ...    ...    ...    ...   ...    ...      ...
# 71  72    景点及旅游  2218.950   -3.71   7.76   9.74  -1.98    22  *ST西域     2.45
# 72  73    农产品加工  3800.900   -4.30  21.22  28.11  -6.90    36   天康生物     1.52
# 73  74      养殖业  2572.980   -4.37  19.60  26.62  -7.02    27  *ST华英     2.14
# 74  75    酒店及餐饮  1345.850   -5.68   4.24   5.94  -1.70    11   锦江酒店    -1.60
# 75  76   种植业与林业  3238.750   -5.84  23.28  27.05  -3.77    21   苏垦农发    -0.69
# ...

# %%
import akshare as ak
from datetime import date
import mplfinance as mpf


def print_K_line(stock_code: str = "sh601398", start_time: str = "2018-05-01", end_time: str = "2018-12-30"):
    print("股票K线", stock_code, "开始时间：", start_time, "结束时间：", end_time)
    start_time = start_time.replace("-", "")
    end_time = end_time.replace("-", "")
    df = ak.stock_zh_a_daily(stock_code, start_time, end_time, adjust="qfq")
    df.set_index('date', inplace=True)
    mpf.plot(data=df)


def get_sz_index_daily(start_time: str = "2018-05-01", end_time: str = "2018-12-30"):
    print("上证K线 ", "开始时间：", start_time, "结束时间：", end_time)
    stock_zh_index_daily_df = ak.stock_zh_index_daily(symbol="sh000001")
    stock_zh_index_daily_df.set_index('date', inplace=True)
    start = date.fromisoformat(start_time)
    end = date.fromisoformat(end_time)
    stock_zh_index_daily_df = stock_zh_index_daily_df[start:end]
    stock_zh_index_daily_df.index = pd.to_datetime(stock_zh_index_daily_df.index)
    mpf.plot(data=stock_zh_index_daily_df)

# %% [markdown]
# # 大盘突破3000点时的K线

# %%
start_time = '2018-05-01'
end_time = '2019-12-30'
print("上证指数")
get_sz_index_daily(start_time, end_time)
# Out:
# 上证指数

# %% [markdown]
# # 银行突破3000点时的K线

# %%
print("工行K线")
print_K_line("sh601398", start_time, end_time)
print("农行K线")
print_K_line("sh601288", start_time, end_time)
print("招行K线")
print_K_line("sh600036", start_time, end_time)
print("建行K线")
print_K_line("sh601939", start_time, end_time)
# Out:
# 工行K线
# 农行K线
# 招行K线
# 建行K线

# %% [markdown]
# # 证券突破3000点时的K线

# %%
print("中信证券K线")
print_K_line("sh600030", start_time, end_time)
print("国泰君安K线")
print_K_line("sh601211", start_time, end_time)
# print("中金公司K线")
# print_K_line("sh601995",start_time,end_time)
print("中信建投K线")
print_K_line("sh601066", start_time, end_time)

print("华林证券K线")
print_K_line("sz002945", start_time, end_time)
# Out:
# 中信证券K线
# 国泰君安K线
# 中信建投K线

# %%
print(ak.stock_info_sz_name_code())
print(ak.stock_info_sh_name_code())
# Out:
#        板块    A股代码   A股简称      A股上市日期           A股总股本          A股流通股本    所属行业
# 0      主板  000001   平安银行  1991-04-03  19,405,918,198  19,405,546,950   J 金融业
# 1      主板  000002  万  科Ａ  1991-01-29   9,724,196,533   9,717,553,265   K 房地产
# 2      主板  000004   国华网安  1990-12-01     156,003,026     116,330,763  I 信息技术
# 3      主板  000005   ST星源  1990-12-10   1,058,536,842   1,057,946,242  N 公共环保
# 4      主板  000006   深振业Ａ  1992-04-27   1,349,995,046   1,349,995,046   K 房地产
# ...   ...     ...    ...         ...             ...             ...     ...
# 2622  创业板  301259   N艾布鲁  2022-04-26     120,000,000      28,452,467  N 公共环保
# 2623  创业板  301263    泰恩康  2022-03-29     236,387,500      56,310,193  F 批发零售
# 2624  创业板  301268    铭利达  2022-04-07     400,010,000      33,805,621   C 制造业
# 2625  创业板  301279   金道科技  2022-04-13     100,000,000      23,778,284   C 制造业
# 2626  创业板  301288    C清研  2022-04-22     108,010,000      23,516,089   C 制造业
#
# [2627 rows x 7 columns]
# ...

# %%
df_sz = ak.stock_info_sz_name_code()
df_sh = ak.stock_info_sh_name_code()

# %%
# 深成指
df_sz[df_sz['板块'] == "主板"]['A股代码'].values
# Out:
# array(['000001', '000002', '000004', ..., '003042', '003043', '003816'],
#       dtype=object)

# %%
# 上证
df_sh[['公司代码', '公司简称']].values
# Out:
# array([['600000', '浦发银行'],
#        ['600004', '白云机场'],
#        ['600006', '东风汽车'],
#        ...,
#        ['605589', '圣泉集团'],
#        ['605598', '上海港湾'],
#        ['605599', '菜百股份']], dtype=object)

# %%
print(df_sh.columns)
print(df_sz.columns)
# Out:
# Index(['公司代码', '公司简称', '代码', '简称', '上市日期'], dtype='object')
# Index(['板块', 'A股代码', 'A股简称', 'A股上市日期', 'A股总股本', 'A股流通股本', '所属行业'], dtype='object')

# %%
tmp_df = pd.DataFrame()

# %%
code = "sh600000"
df = ak.stock_zh_a_daily(code, '20220104', '20220105', adjust="qfq")
df["code"] = code
print(df.tail())
print(df.dtypes)
tmp_df = tmp_df.append(df, ignore_index=True)
print(tmp_df.shape)

# %%
code = "sz000002"
df = ak.stock_zh_a_daily(code, '20220104', '20220105', adjust="qfq")
df["code"] = code
print(df.tail())
print(df.dtypes)
tmp_df = tmp_df.append(df, ignore_index=True)
print(tmp_df.shape)
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
#
#    turnover      code
# 0  0.020038  sz000002
# 1  0.019866  sz000002
# date                 datetime64[ns]
# open                        float64
# high                        float64
# low                         float64
# close                       float64
# volume                      float64
# outstanding_share           float64
# turnover                    float64
# code                         object
# dtype: object
# (14, 9)

# %%
tmp_df
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
# 2 2022-01-06  21.12  21.66  20.79  21.05  138027406.0       9.717553e+09
# 3 2022-01-07  21.38  22.46  21.35  21.89  226276805.0       9.717553e+09
# 4 2022-01-10  21.80  22.66  21.56  22.16  152779663.0       9.717553e+09
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
# 2 2022-01-06  21.12  21.66  20.79  21.05  138027406.0       9.717553e+09
# 3 2022-01-07  21.38  22.46  21.35  21.89  226276805.0       9.717553e+09
# 4 2022-01-10  21.80  22.66  21.56  22.16  152779663.0       9.717553e+09
#
#    turnover      code
# 0  0.020038  sz000002
# 1  0.019866  sz000002
# 2  0.014204  sz000002
# 3  0.023285  sz000002
# 4  0.015722  sz000002
# 0  0.020038  sz000002
# ...

# %%
# 获取深圳代码
codes = df_sz[df_sz['板块'] == "主板"]['A股代码'].values[1:2]
print(codes)

tmp_df = pd.DataFrame()
for code in codes:
    code = "sz" + code
    df = ak.stock_zh_a_daily(code, '20220104', '20220105', adjust="qfq")
    df["code"] = code
    tmp_df = tmp_df.append(df, ignore_index=True)
# 获取上海代码
codes = df_sh['公司代码'].values[1:2]
print(codes)

for code in codes:
    code = "sh" + code
    df = ak.stock_zh_a_daily(code, '20220104', '20220105', adjust="qfq")
    df["code"] = code
    tmp_df = tmp_df.append(df, ignore_index=True)
# Out:
# ['000002']
# ['600004']

# %%
tmp_df
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
# 2 2022-01-04  12.04  12.50  11.98  12.46   27874372.0       2.069321e+09
# 3 2022-01-05  12.41  13.11  12.38  12.83   54939067.0       2.069321e+09
#
#    turnover      code
# 0  0.020038  sz000002
# 1  0.019866  sz000002
# 2  0.013470  sh600004
# 3  0.026549  sh600004

# %%
stock = tmp_df[tmp_df['code'] == 'sz000002']
stock['rise_rate'] = (stock['close'] - stock['open']) / stock['open']

# %%
stock.tail()
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
#
#    turnover      code  rise_rate
# 0  0.020038  sz000002   0.051308
# 1  0.019866  sz000002   0.036221

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
# ----> 1 stock['last_days_rate']=stock[stock.iloc[stock.index-1]['rise_rate']]
#
# File ~/gitee/financial_lab/venv/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/gitee/financial_lab/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
# ...

# %%
stock1 = stock.drop(index=0, axis=0)
stock1 = stock1.drop(columns=['level_0'])
stock1.tail()

# %%
stock1 = stock1.reset_index(drop=False)
stock1 = stock1.drop(columns=['index'])
stock1.tail()
stock['last_rate'] = stock1['rise_rate']

stock.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [122], in <cell line: 1>()
# ----> 1 stock1 = stock1.drop(columns=['index'])
#
# File ~/gitee/financial_lab/venv/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/gitee/financial_lab/venv/lib/python3.8/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
# 数据后移一位
# 删除最后一行，然后index+1
stock1 = stock.drop(len(stock) - 1, axis=0)
stock1.tail()
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
#
#    turnover      code  rise_rate
# 0  0.020038  sz000002   0.051308

# %%
stock1.index += 1

# %%
stock1.tail()
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 1 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
#
#    turnover      code  rise_rate
# 1  0.020038  sz000002   0.051308

# %%
stock['last_rate'] = stock1['rise_rate']

# %%
stock.tail()
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
#
#    turnover      code  rise_rate  last_rate
# 0  0.020038  sz000002   0.051308        NaN
# 1  0.019866  sz000002   0.036221   0.051308

# %%
stock[(stock['rise_rate'] < 0.05) & (stock['last_rate'] > 0.05)]
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
#
#    turnover      code  rise_rate  last_rate
# 1  0.019866  sz000002   0.036221   0.051308

# %%
codes = tmp_df['code'].unique()

stocks = tmp_df

# %%
tmp_df_1 = pd.DataFrame()
for code in codes:
    # 取index
    single_stock = tmp_df[tmp_df['code'] == code]
    # 重新index
    single_stock = single_stock.reset_index(drop=False)
    single_stock = single_stock.drop(columns=['index'])
    # 添加增长率
    single_stock['rise_rate'] = (single_stock['close'] - single_stock['open']) / single_stock['open']
    last_day = single_stock.drop(len(single_stock) - 1, axis=0)
    last_day.index += 1
    single_stock['before_day_rate'] = last_day['rise_rate']
    print(single_stock)
    tmp_df_1 = tmp_df_1.append(single_stock)
# Out:
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
#
#    turnover      code  rise_rate  before_day_rate
# 0  0.020038  sz000002   0.051308              NaN
# 1  0.019866  sz000002   0.036221         0.051308
#         date   open   high    low  close      volume  outstanding_share  \
# 0 2022-01-04  12.04  12.50  11.98  12.46  27874372.0       2.069321e+09
# 1 2022-01-05  12.41  13.11  12.38  12.83  54939067.0       2.069321e+09
#
#    turnover      code  rise_rate  before_day_rate
# 0  0.013470  sh600004   0.034884              NaN
# 1  0.026549  sh600004   0.033844         0.034884
#         date   open   high    low  close       volume  outstanding_share  \
# 0 2022-01-04  19.49  20.65  19.36  20.49  194720202.0       9.717553e+09
# 1 2022-01-05  20.43  21.61  20.36  21.17  193045791.0       9.717553e+09
# ...

# %%
def add_before_rate(df):

    tmp_df = pd.DataFrame()
    # 获得codes
    codes = df['code'].unique()
    for code in codes:
        # 取单只股票
        single_stock = df[df['code'] == code]
        # 重新index
        single_stock = single_stock.reset_index(drop=False)
        single_stock = single_stock.drop(columns=['index'])
        # 添加增长率
        single_stock['rise_rate'] = (single_stock['close'] - single_stock['open']) / single_stock['open']
        last_day = single_stock.drop(len(single_stock) - 1, axis=0)
        last_day.index += 1
        single_stock['before_day_rate'] = last_day['rise_rate']
        tmp_df = tmp_df.append(single_stock)
    tmp_df = tmp_df.reset_index(drop=False)
    tmp_df = tmp_df.drop(columns=['index'])
    return tmp_df

# %%
test_df = add_before_rate(tmp_df)
test_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 test_df = add_before_rate(tmp_df)
#       2 test_df
#
# NameError: name 'add_before_rate' is not defined

# %%
# word2vec
